# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Name" : ["Jhon","anna","peter","Linda"],
    "Age": [28,34,29,42],
    "City":["New York","Paris","Berlin","London"],
    "Salary":[65000,70000,62000,85000]
}
labels= ["a","b","c","d"]

# %%
df =pd.DataFrame(data,index =labels)

# %%
df
# Out:
#     Name  Age      City  Salary
# a   Jhon   28  New York   65000
# b   anna   34     Paris   70000
# c  peter   29    Berlin   62000
# d  Linda   42    London   85000

# %%
data_list = [
    ["Jhon" ,28,"New York",65000],
    ["Anna",34,"Paris",70000],
    ["Peter",29,"Berlin",62000],
    ["Linda",42,"London",850000]
]
labels= ["a","b","c","d"]
columns = ["Name","Age","City","Salary"]

df2=pd.DataFrame(data_list,columns = columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London  850000

# %% [markdown]
# **Selection and Indexing columns**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London  850000

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   Jhon  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **Creating a new colum**

# %%
df2["Designation"] = ["Doctor","Engineer","Doctor",'Engineer']

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   Jhon   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London  850000    Engineer

# %% [markdown]
# **Remove columns**

# %%
df2.drop("Designation",axis =1,inplace =True)
df2
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London  850000

# %% [markdown]
# **Selecting rows**

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  Jhon   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary    850000
# Name: 3, dtype: object

# %% [markdown]
# **Selecting subset of rows and columns**

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London  850000

# %%
df2.loc[[2,0]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 0   Jhon   28

# %% [markdown]
# **Conditional Selection**

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London  850000

# %%
# Want to see poeple whoes age is above 30  # mversion
a=df2["Age"]
b=a>30

df2[b]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London  850000

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London  850000

# %% [markdown]
# I only want people whose age is above 30 and their city must be paris

# %%
df2[(df2["Age"]>30) & (df2["City"]== "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
